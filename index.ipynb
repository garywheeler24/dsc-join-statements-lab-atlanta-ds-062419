# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge of join statements, using various types of joins and various methods for specifying the links between them.
#
# ## Objectives
#
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table you will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, you'll use the same Customer Relationship Management (CRM) database that you saw from the previous lesson.
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
import sqlite3 
import pandas as pd
conn = sqlite3.connect('data.sqlite')
c = conn.cursor()



#Your code here

# %% [markdown]
# ## Display the names of all the employees in Boston.
# Hint: join the employees and offices tables.

# %%
c.execute("""select * from employees join offices""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]

df

#Your code here
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1002     Murphy     Diane     x5800
# 1             1002     Murphy     Diane     x5800
# 2             1002     Murphy     Diane     x5800
# 3             1002     Murphy     Diane     x5800
# 4             1002     Murphy     Diane     x5800
# 5             1002     Murphy     Diane     x5800
# 6             1002     Murphy     Diane     x5800
# 7             1056  Patterson      Mary     x4611
# 8             1056  Patterson      Mary     x4611
# 9             1056  Patterson      Mary     x4611
# 10            1056  Patterson      Mary     x4611
# 11            1056  Patterson      Mary     x4611
# 12            1056  Patterson      Mary     x4611
# 13            1056  Patterson      Mary     x4611
# 14            1076   Firrelli      Jeff     x9273
# 15            1076   Firrelli      Jeff     x9273
# 16            1076   Firrelli      Jeff     x9273
# 17            1076   Firrelli      Jeff     x9273
# 18            1076   Firrelli      Jeff     x9273
# 19            1076   Firrelli      Jeff     x9273
# 20            1076   Firrelli      Jeff     x9273
# 21            1088  Patterson   William     x4871
# 22            1088  Patterson   William     x4871
# 23            1088  Patterson   William     x4871
# 24            1088  Patterson   William     x4871
# 25            1088  Patterson   William     x4871
# 26            1088  Patterson   William     x4871
# 27            1088  Patterson   William     x4871
# 28            1102     Bondur    Gerard     x5408
# 29            1102     Bondur    Gerard     x5408
# ..             ...        ...       ...       ...
# 131           1612      Marsh     Peter      x102
# 132           1612      Marsh     Peter      x102
# 133           1619       King       Tom      x103
# 134           1619       King       Tom      x103
# 135           1619       King       Tom      x103
# 136           1619       King       Tom      x103
# 137           1619       King       Tom      x103
# 138           1619       King       Tom      x103
# 139           1619       King       Tom      x103
# 140           1621      Nishi      Mami      x101
# 141           1621      Nishi      Mami      x101
# 142           1621      Nishi      Mami      x101
# 143           1621      Nishi      Mami      x101
# 144           1621      Nishi      Mami      x101
# 145           1621      Nishi      Mami      x101
# 146           1621      Nishi      Mami      x101
# 147           1625       Kato   Yoshimi      x102
# 148           1625       Kato   Yoshimi      x102
# 149           1625       Kato   Yoshimi      x102
# 150           1625       Kato   Yoshimi      x102
# 151           1625       Kato   Yoshimi      x102
# 152           1625       Kato   Yoshimi      x102
# 153           1625       Kato   Yoshimi      x102
# 154           1702     Gerard    Martin     x2312
# 155           1702     Gerard    Martin     x2312
# 156           1702     Gerard    Martin     x2312
# 157           1702     Gerard    Martin     x2312
# 158           1702     Gerard    Martin     x2312
# 159           1702     Gerard    Martin     x2312
# 160           1702     Gerard    Martin     x2312
#
#                                email officeCode reportsTo  \
# 0       dmurphy@classicmodelcars.com          1
# 1       dmurphy@classicmodelcars.com          1
# 2       dmurphy@classicmodelcars.com          1
# 3       dmurphy@classicmodelcars.com          1
# 4       dmurphy@classicmodelcars.com          1
# 5       dmurphy@classicmodelcars.com          1
# 6       dmurphy@classicmodelcars.com          1
# 7     mpatterso@classicmodelcars.com          1      1002
# 8     mpatterso@classicmodelcars.com          1      1002
# 9     mpatterso@classicmodelcars.com          1      1002
# 10    mpatterso@classicmodelcars.com          1      1002
# 11    mpatterso@classicmodelcars.com          1      1002
# 12    mpatterso@classicmodelcars.com          1      1002
# 13    mpatterso@classicmodelcars.com          1      1002
# 14    jfirrelli@classicmodelcars.com          1      1002
# 15    jfirrelli@classicmodelcars.com          1      1002
# 16    jfirrelli@classicmodelcars.com          1      1002
# 17    jfirrelli@classicmodelcars.com          1      1002
# 18    jfirrelli@classicmodelcars.com          1      1002
# 19    jfirrelli@classicmodelcars.com          1      1002
# 20    jfirrelli@classicmodelcars.com          1      1002
# 21   wpatterson@classicmodelcars.com          6      1056
# 22   wpatterson@classicmodelcars.com          6      1056
# 23   wpatterson@classicmodelcars.com          6      1056
# 24   wpatterson@classicmodelcars.com          6      1056
# 25   wpatterson@classicmodelcars.com          6      1056
# 26   wpatterson@classicmodelcars.com          6      1056
# 27   wpatterson@classicmodelcars.com          6      1056
# 28      gbondur@classicmodelcars.com          4      1056
# 29      gbondur@classicmodelcars.com          4      1056
# ..                               ...        ...       ...
# 131      pmarsh@classicmodelcars.com          6      1088
# 132      pmarsh@classicmodelcars.com          6      1088
# 133       tking@classicmodelcars.com          6      1088
# 134       tking@classicmodelcars.com          6      1088
# 135       tking@classicmodelcars.com          6      1088
# 136       tking@classicmodelcars.com          6      1088
# 137       tking@classicmodelcars.com          6      1088
# 138       tking@classicmodelcars.com          6      1088
# 139       tking@classicmodelcars.com          6      1088
# 140      mnishi@classicmodelcars.com          5      1056
# 141      mnishi@classicmodelcars.com          5      1056
# 142      mnishi@classicmodelcars.com          5      1056
# 143      mnishi@classicmodelcars.com          5      1056
# 144      mnishi@classicmodelcars.com          5      1056
# 145      mnishi@classicmodelcars.com          5      1056
# 146      mnishi@classicmodelcars.com          5      1056
# 147       ykato@classicmodelcars.com          5      1621
# 148       ykato@classicmodelcars.com          5      1621
# 149       ykato@classicmodelcars.com          5      1621
# 150       ykato@classicmodelcars.com          5      1621
# 151       ykato@classicmodelcars.com          5      1621
# 152       ykato@classicmodelcars.com          5      1621
# 153       ykato@classicmodelcars.com          5      1621
# 154     mgerard@classicmodelcars.com          4      1102
# 155     mgerard@classicmodelcars.com          4      1102
# 156     mgerard@classicmodelcars.com          4      1102
# 157     mgerard@classicmodelcars.com          4      1102
# 158     mgerard@classicmodelcars.com          4      1102
# 159     mgerard@classicmodelcars.com          4      1102
# 160     mgerard@classicmodelcars.com          4      1102
#
#                  jobTitle officeCode           city             phone  \
# 0               President          1  San Francisco   +1 650 219 4782
# 1               President          2         Boston   +1 215 837 0825
# 2               President          3            NYC   +1 212 555 3000
# 3               President          4          Paris   +33 14 723 4404
# 4               President          5          Tokyo   +81 33 224 5000
# 5               President          6         Sydney   +61 2 9264 2451
# 6               President          7         London  +44 20 7877 2041
# 7                VP Sales          1  San Francisco   +1 650 219 4782
# 8                VP Sales          2         Boston   +1 215 837 0825
# 9                VP Sales          3            NYC   +1 212 555 3000
# 10               VP Sales          4          Paris   +33 14 723 4404
# 11               VP Sales          5          Tokyo   +81 33 224 5000
# 12               VP Sales          6         Sydney   +61 2 9264 2451
# 13               VP Sales          7         London  +44 20 7877 2041
# 14           VP Marketing          1  San Francisco   +1 650 219 4782
# 15           VP Marketing          2         Boston   +1 215 837 0825
# 16           VP Marketing          3            NYC   +1 212 555 3000
# 17           VP Marketing          4          Paris   +33 14 723 4404
# 18           VP Marketing          5          Tokyo   +81 33 224 5000
# 19           VP Marketing          6         Sydney   +61 2 9264 2451
# 20           VP Marketing          7         London  +44 20 7877 2041
# 21   Sales Manager (APAC)          1  San Francisco   +1 650 219 4782
# 22   Sales Manager (APAC)          2         Boston   +1 215 837 0825
# 23   Sales Manager (APAC)          3            NYC   +1 212 555 3000
# 24   Sales Manager (APAC)          4          Paris   +33 14 723 4404
# 25   Sales Manager (APAC)          5          Tokyo   +81 33 224 5000
# 26   Sales Manager (APAC)          6         Sydney   +61 2 9264 2451
# 27   Sales Manager (APAC)          7         London  +44 20 7877 2041
# 28    Sale Manager (EMEA)          1  San Francisco   +1 650 219 4782
# 29    Sale Manager (EMEA)          2         Boston   +1 215 837 0825
# ..                    ...        ...            ...               ...
# 131             Sales Rep          6         Sydney   +61 2 9264 2451
# 132             Sales Rep          7         London  +44 20 7877 2041
# 133             Sales Rep          1  San Francisco   +1 650 219 4782
# 134             Sales Rep          2         Boston   +1 215 837 0825
# 135             Sales Rep          3            NYC   +1 212 555 3000
# 136             Sales Rep          4          Paris   +33 14 723 4404
# 137             Sales Rep          5          Tokyo   +81 33 224 5000
# 138             Sales Rep          6         Sydney   +61 2 9264 2451
# 139             Sales Rep          7         London  +44 20 7877 2041
# 140             Sales Rep          1  San Francisco   +1 650 219 4782
# 141             Sales Rep          2         Boston   +1 215 837 0825
# 142             Sales Rep          3            NYC   +1 212 555 3000
# 143             Sales Rep          4          Paris   +33 14 723 4404
# 144             Sales Rep          5          Tokyo   +81 33 224 5000
# 145             Sales Rep          6         Sydney   +61 2 9264 2451
# 146             Sales Rep          7         London  +44 20 7877 2041
# 147             Sales Rep          1  San Francisco   +1 650 219 4782
# 148             Sales Rep          2         Boston   +1 215 837 0825
# 149             Sales Rep          3            NYC   +1 212 555 3000
# 150             Sales Rep          4          Paris   +33 14 723 4404
# 151             Sales Rep          5          Tokyo   +81 33 224 5000
# 152             Sales Rep          6         Sydney   +61 2 9264 2451
# 153             Sales Rep          7         London  +44 20 7877 2041
# 154             Sales Rep          1  San Francisco   +1 650 219 4782
# 155             Sales Rep          2         Boston   +1 215 837 0825
# 156             Sales Rep          3            NYC   +1 212 555 3000
# 157             Sales Rep          4          Paris   +33 14 723 4404
# 158             Sales Rep          5          Tokyo   +81 33 224 5000
# 159             Sales Rep          6         Sydney   +61 2 9264 2451
# 160             Sales Rep          7         London  +44 20 7877 2041
#
#                  addressLine1 addressLine2       state    country postalCode  \
# 0           100 Market Street    Suite 300          CA        USA      94080
# 1            1550 Court Place    Suite 102          MA        USA      02107
# 2        523 East 53rd Street      apt. 5A          NY        USA      10022
# 3    43 Rue Jouffroy D'abbans                              France      75017
# 4                 4-1 Kioicho               Chiyoda-Ku      Japan   102-8578
# 5       5-11 Wentworth Avenue     Floor #2              Australia   NSW 2010
# 6         25 Old Broad Street      Level 7                     UK   EC2N 1HN
# 7           100 Market Street    Suite 300          CA        USA      94080
# 8            1550 Court Place    Suite 102          MA        USA      02107
# 9        523 East 53rd Street      apt. 5A          NY        USA      10022
# 10   43 Rue Jouffroy D'abbans                              France      75017
# 11                4-1 Kioicho               Chiyoda-Ku      Japan   102-8578
# 12      5-11 Wentworth Avenue     Floor #2              Australia   NSW 2010
# 13        25 Old Broad Street      Level 7                     UK   EC2N 1HN
# 14          100 Market Street    Suite 300          CA        USA      94080
# 15           1550 Court Place    Suite 102          MA        USA      02107
# 16       523 East 53rd Street      apt. 5A          NY        USA      10022
# 17   43 Rue Jouffroy D'abbans                              France      75017
# 18                4-1 Kioicho               Chiyoda-Ku      Japan   102-8578
# 19      5-11 Wentworth Avenue     Floor #2              Australia   NSW 2010
# 20        25 Old Broad Street      Level 7                     UK   EC2N 1HN
# 21          100 Market Street    Suite 300          CA        USA      94080
# 22           1550 Court Place    Suite 102          MA        USA      02107
# 23       523 East 53rd Street      apt. 5A          NY        USA      10022
# 24   43 Rue Jouffroy D'abbans                              France      75017
# 25                4-1 Kioicho               Chiyoda-Ku      Japan   102-8578
# 26      5-11 Wentworth Avenue     Floor #2              Australia   NSW 2010
# 27        25 Old Broad Street      Level 7                     UK   EC2N 1HN
# 28          100 Market Street    Suite 300          CA        USA      94080
# 29           1550 Court Place    Suite 102          MA        USA      02107
# ..                        ...          ...         ...        ...        ...
# 131     5-11 Wentworth Avenue     Floor #2              Australia   NSW 2010
# 132       25 Old Broad Street      Level 7                     UK   EC2N 1HN
# 133         100 Market Street    Suite 300          CA        USA      94080
# 134          1550 Court Place    Suite 102          MA        USA      02107
# 135      523 East 53rd Street      apt. 5A          NY        USA      10022
# 136  43 Rue Jouffroy D'abbans                              France      75017
# 137               4-1 Kioicho               Chiyoda-Ku      Japan   102-8578
# 138     5-11 Wentworth Avenue     Floor #2              Australia   NSW 2010
# 139       25 Old Broad Street      Level 7                     UK   EC2N 1HN
# 140         100 Market Street    Suite 300          CA        USA      94080
# 141          1550 Court Place    Suite 102          MA        USA      02107
# 142      523 East 53rd Street      apt. 5A          NY        USA      10022
# 143  43 Rue Jouffroy D'abbans                              France      75017
# 144               4-1 Kioicho               Chiyoda-Ku      Japan   102-8578
# 145     5-11 Wentworth Avenue     Floor #2              Australia   NSW 2010
# 146       25 Old Broad Street      Level 7                     UK   EC2N 1HN
# 147         100 Market Street    Suite 300          CA        USA      94080
# 148          1550 Court Place    Suite 102          MA        USA      02107
# 149      523 East 53rd Street      apt. 5A          NY        USA      10022
# 150  43 Rue Jouffroy D'abbans                              France      75017
# 151               4-1 Kioicho               Chiyoda-Ku      Japan   102-8578
# 152     5-11 Wentworth Avenue     Floor #2              Australia   NSW 2010
# 153       25 Old Broad Street      Level 7                     UK   EC2N 1HN
# 154         100 Market Street    Suite 300          CA        USA      94080
# 155          1550 Court Place    Suite 102          MA        USA      02107
# 156      523 East 53rd Street      apt. 5A          NY        USA      10022
# 157  43 Rue Jouffroy D'abbans                              France      75017
# 158               4-1 Kioicho               Chiyoda-Ku      Japan   102-8578
# 159     5-11 Wentworth Avenue     Floor #2              Australia   NSW 2010
# 160       25 Old Broad Street      Level 7                     UK   EC2N 1HN
#
#     territory
# 0          NA
# 1          NA
# 2          NA
# 3        EMEA
# 4       Japan
# 5        APAC
# 6        EMEA
# 7          NA
# 8          NA
# 9          NA
# 10       EMEA
# 11      Japan
# 12       APAC
# 13       EMEA
# 14         NA
# 15         NA
# 16         NA
# 17       EMEA
# 18      Japan
# 19       APAC
# 20       EMEA
# 21         NA
# 22         NA
# 23         NA
# 24       EMEA
# 25      Japan
# 26       APAC
# 27       EMEA
# 28         NA
# 29         NA
# ..        ...
# 131      APAC
# 132      EMEA
# 133        NA
# 134        NA
# 135        NA
# 136      EMEA
# 137     Japan
# 138      APAC
# 139      EMEA
# 140        NA
# 141        NA
# 142        NA
# 143      EMEA
# 144     Japan
# 145      APAC
# 146      EMEA
# 147        NA
# 148        NA
# 149        NA
# 150      EMEA
# 151     Japan
# 152      APAC
# 153      EMEA
# 154        NA
# 155        NA
# 156        NA
# 157      EMEA
# 158     Japan
# 159      APAC
# 160      EMEA
#
# [161 rows x 17 columns]

# %% [markdown]
# ## Do any offices have no employees?
# Hint: Combine the employees and offices tables and use a group by.

# %%
c.execute("""select city, count(*) from offices left join employees using(officecode) group by 1 
""")

df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
#Your code here
# Out:
#             city  count(*)
# 0         Boston         2
# 1         London         2
# 2            NYC         2
# 3          Paris         5
# 4  San Francisco         6
# 5         Sydney         4
# 6          Tokyo         2

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Answers will vary

# %%
# Your code here

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the Number of Products each employee has sold

# %%
#Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You now know how to use join statements, along with leveraging your foreign keys knowledge!
